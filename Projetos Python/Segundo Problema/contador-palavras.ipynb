# %% [markdown]
# ## Problema Geral: Contador de Palavras
#
# ### Abstração:
# - Entrada e processamento de dados;
# - Criar a contagem das palavras;
# - Exibir a contagem;
# - Testar e refinar o código;
