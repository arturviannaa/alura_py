# %% [markdown]
# ## Aprendendo condicionais

# %%
nome = "Alura"

if nome == "Alura":
    print("Bem-vindo à Alura!")
elif nome == "Latam":
    print("Bem-vindo à Latam!")
else:
    print("Nome desconhecido.")
# Out:
# Bem-vindo à Alura!

# %% [markdown]
# ### Operadores de comparação
# - Maior que (>): Verifica se um valor é maior que outro
# - Menor que (<): Verifica se um valor é menor que outro
# - Igual a (==): Verifica se um valor é igual a outro
# - Diferente de (!=): Verifica se um valor é diferente de outro
# - Maior ou igual a (>=): Verifica se um valor é maior ou igual a outro
# - Menor ou igual a (<=): Verifica se um valor é menor ou igual a outro

# %%
## Código AND

idade = int(input("Informe sua idade: "))
tem_documento = input("Tem documento? (sim/não): ").lower().strip()

if idade >= 18 and tem_documento == "sim":
    print("Entrada permitida!")
else:
    print("Entrada negada.")
# Out:
# Entrada permitida!

# %%
## Código OR

feriado = input("Hoje é feriado? (sim/não): ").lower().strip()
folga = input("Você tem folga hoje? (sim/não): ").lower().strip()

if feriado == "sim" or folga == "sim":
    print("Você pode descansar hoje!")
else:
    print("Dia normal de trabalho.")
# Out:
# Você pode descansar hoje!
