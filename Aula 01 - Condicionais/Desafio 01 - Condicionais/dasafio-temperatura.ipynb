# %% [markdown]
# ### Desafio de condicionais:
#
# Lucas trabalha em TI e precisa garantir que a temperatura de uma sala de servidores não ultrapasse 25°C.
# Ele quer um programa que receba a temperatura atual como entrada e, se necessário, exiba uma mensagem de alerta.

# %%
TEMPERATURA_LIMITE = 25
temperatura_atual = int(input('Qual a temperatura atual? '))

if temperatura_atual > TEMPERATURA_LIMITE:
    print("Alerta! A temperatura está acima do limite permitido.")
# Out:
# Alerta! A temperatura está acima do limite permitido.
